# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

model1 = LogisticRegression()
model2 = DecisionTreeClassifier()
model3 = SVC(probability=True)  # Required for soft voting

voting_clf = VotingClassifier(
    estimators=[('lr', model1), ('dt', model2), ('svc', model3)],
    voting='soft'  # 'hard' for majority voting
)
voting_clf.fit(X_train, y_train)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from mlxtend.classifier import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

base_models = [
    DecisionTreeClassifier(),
    SVC(probability=True)
]

meta_model = LogisticRegression()

stack_clf = StackingClassifier(classifiers=base_models, meta_classifier=meta_model)
stack_clf.fit(X_train, y_train)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.ensemble import RandomForestClassifier #if decision tree is base model then it called randomforest instead {ensemble}

rf = RandomForestClassifier(n_estimators=100, max_features='sqrt')
rf.fit(X_train, y_train)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import xgboost as xgb

model = xgb.XGBClassifier(n_estimators=100, learning_rate=0.1)
model.fit(X_train, y_train)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
