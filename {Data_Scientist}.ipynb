# %% [markdown]
# %%markdown
#
# # 📘 Full-Stack Data Scientist Learning Roadmap (Free Resources Included)
#
# This roadmap outlines **all essential tools**, their **purpose**, and the **top free resources** you can use to **stand out in the job market** as a dynamic, full-stack data scientist.
#
# ---
#
# ## 🔧 Programming & Scripting
#
# | Tool/Tech              | Purpose                                       | Free Resource                                                                 |
# |------------------------|-----------------------------------------------|-------------------------------------------------------------------------------|
# | **Python**             | Core ML language, data analysis, scripting    | [Python for Everybody](https://www.coursera.org/specializations/python)      |
# | **Bash / Shell**       | Automation and server tasks                   | [The Bash Guide](https://guide.bash.academy/)                                |
#
# ---
#
# ## 📊 Data Analysis & Visualization
#
# | Tool/Tech         | Purpose                                         | Free Resource                                                                     |
# |-------------------|-------------------------------------------------|------------------------------------------------------------------------------------|
# | **NumPy**         | Numerical computing, matrix operations          | [NumPy Docs](https://numpy.org/doc/stable/)                                       |
# | **Pandas**        | Data wrangling and preprocessing                | [Pandas Docs](https://pandas.pydata.org/docs/)                                    |
# | **Matplotlib**    | Basic static visualization                      | [Matplotlib Tutorial](https://www.youtube.com/watch?v=3Xc3CA655Y4)                |
# | **Seaborn**       | Statistical plots                               | [Seaborn Docs](https://seaborn.pydata.org/tutorial.html)                          |
# | **Plotly/Altair** | Interactive visualizations                      | [Plotly Express Docs](https://plotly.com/python/plotly-express/)                 |
#
# ---
#
# ## 🤖 Machine Learning
#
# | Tool/Tech          | Purpose                                          | Free Resource                                                                 |
# |--------------------|--------------------------------------------------|--------------------------------------------------------------------------------|
# | **Scikit-learn**   | Traditional ML algorithms                        | [Scikit-learn Docs](https://scikit-learn.org/stable/)                          |
# | **XGBoost/LightGBM**| Boosted decision trees                          | [XGBoost Docs](https://xgboost.readthedocs.io/)                                |
# | **MLflow**         | ML lifecycle tracking                           | [MLflow GitHub](https://github.com/mlflow/mlflow)                              |
#
# ---
#
# ## 🧠 Deep Learning
#
# | Tool/Tech           | Purpose                                         | Free Resource                                                                  |
# |---------------------|-------------------------------------------------|---------------------------------------------------------------------------------|
# | **TensorFlow/Keras**| Build neural networks                          | [DeepLearning.AI YouTube](https://www.youtube.com/c/DeepLearningAI)            |
# | **PyTorch**         | Dynamic deep learning                          | [PyTorch Tutorials](https://pytorch.org/tutorials/)                            |
#
# ---
#
# ## 🌐 Web App Deployment
#
# | Tool/Tech     | Purpose                                    | Free Resource                                                                 |
# |---------------|--------------------------------------------|--------------------------------------------------------------------------------|
# | **Flask**     | Lightweight web apps                       | [Flask Mega-Tutorial](https://blog.miguelgrinberg.com/post/the-flask-mega-tutorial-part-i-hello-world) |
# | **Streamlit** | Data dashboards and UI                     | [Streamlit Docs](https://docs.streamlit.io/)                                  |
#
# ---
#
# ## 🐳 Cloud & DevOps
#
# | Tool/Tech          | Purpose                                         | Free Resource                                                              |
# |--------------------|-------------------------------------------------|-----------------------------------------------------------------------------|
# | **Docker**         | Containerization                               | [Docker Docs](https://docs.docker.com/get-started/)                        |
# | **Git & GitHub**   | Version control, code collaboration            | [GitHub Learning Lab](https://lab.github.com/)                             |
# | **GitHub Actions** | CI/CD for automation                           | [GitHub Actions Docs](https://docs.github.com/en/actions)                 |
#
# ---
#
# ## 🗃️ Databases
#
# | Tool/Tech           | Purpose                                    | Free Resource                                                                      |
# |---------------------|--------------------------------------------|-------------------------------------------------------------------------------------|
# | **SQL (PostgreSQL)**| Structured data querying                   | [Mode SQL Tutorial](https://mode.com/sql-tutorial/)                                |
# | **MongoDB**         | NoSQL for unstructured data                | [MongoDB University](https://university.mongodb.com/)                              |
#
# ---
#
# ## 🔥 Big Data & Pipelines
#
# | Tool/Tech       | Purpose                               | Free Resource                                                                      |
# |------------------|----------------------------------------|-------------------------------------------------------------------------------------|
# | **Apache Spark** | Distributed data processing           | [Databricks YouTube](https://www.youtube.com/c/databricks)                         |
# | **Apache Airflow**| Workflow orchestration               | [Airflow Docs](https://airflow.apache.org/docs/apache-airflow/stable/)            |
# | **Kafka**        | Real-time stream processing           | [Kafka Developer Courses](https://developer.confluent.io/learn-kafka/)            |
#
# ---
#
# ## 📊 BI & Analytics
#
# | Tool/Tech         | Purpose                                        | Free Resource                                                                    |
# |-------------------|------------------------------------------------|-----------------------------------------------------------------------------------|
# | **Power BI**      | Dashboards and analytics                      | [Power BI Guided Learning](https://learn.microsoft.com/en-us/training/powerplatform/power-bi/) |
# | **Tableau (Public)**| Visual analytics                           | [Tableau Free Training](https://www.tableau.com/learn/training/20201)           |
#
# ---
#
# ## 🧠 NLP & CV (Optional Specializations)
#
# | Tool/Tech         | Purpose                                        | Free Resource                                                                      |
# |-------------------|------------------------------------------------|-------------------------------------------------------------------------------------|
# | **HuggingFace**   | NLP, Transformers, Computer Vision            | [HF Course](https://huggingface.co/learn/nlp-course/)                              |
#
# ---
#
# ## 💼 Portfolio & Branding
#
# | Tool/Tech         | Purpose                                        | Free Resource                                                                      |
# |-------------------|------------------------------------------------|-------------------------------------------------------------------------------------|
# | **GitHub**        | Project showcase                               | [Awesome Data Science Repos](https://github.com/academic/awesome-datascience)      |
# | **LinkedIn**      | Professional presence                          | [LinkedIn Tips for DS](https://towardsdatascience.com/tagged/linkedin)            |
#
# ---

# %% [markdown]
# # Full-Stack Data Scientist: Free Resources Roadmap
#
# This document lists essential tools along with free resources available online to help you build a well-rounded skillset—from programming and data manipulation to machine learning, web deployment, and more.
#
# ---
#
# ## 1. Programming & Scripting
#
# - **Python**
#   - [Python for Everybody (Coursera - Free Audit)](https://www.coursera.org/specializations/python)
#   - [Official Python Documentation](https://docs.python.org/3/)
#
# - **Bash / Shell Scripting**
#   - [The Bash Guide](https://guide.bash.academy/)
#
# ---
#
# ## 2. Data Manipulation & Analysis
#
# - **NumPy**
#   - [NumPy Official Documentation](https://numpy.org/doc/stable/)
#   - [W3Schools NumPy Tutorial](https://www.w3schools.com/python/numpy_intro.asp)
#
# - **Pandas**
#   - [Pandas Official Documentation](https://pandas.pydata.org/docs/)
#   - [Kaggle Pandas Course](https://www.kaggle.com/learn/pandas)
#
# ---
#
# ## 3. Data Visualization
#
# - **Matplotlib**
#   - [Matplotlib Basics (YouTube Tutorial)](https://www.youtube.com/watch?v=3Xc3CA655Y4)
#   - [Official Matplotlib Documentation](https://matplotlib.org/stable/contents.html)
#
# - **Seaborn**
#   - [Seaborn Official Tutorial](https://seaborn.pydata.org/tutorial.html)
#
# - **Plotly / Altair**
#   - [Plotly Express Documentation](https://plotly.com/python/plotly-express/)
#   - [Altair Quick Start Guide](https://altair-viz.github.io/)
#
# ---
#
# ## 4. Machine Learning
#
# - **Scikit-learn**
#   - [Scikit-learn Official Documentation](https://scikit-learn.org/stable/)
#   - [Kaggle Intro to Machine Learning](https://www.kaggle.com/learn/intro-to-machine-learning)
#
# - **XGBoost / LightGBM**
#   - [XGBoost Documentation](https://xgboost.readthedocs.io/en/latest/)
#
# - **MLflow**
#   - [MLflow on GitHub](https://github.com/mlflow/mlflow)
#
# ---
#
# ## 5. Deep Learning
#
# - **TensorFlow / Keras**
#   - [TensorFlow Tutorials](https://www.tensorflow.org/tutorials)
#   - [Keras Documentation](https://keras.io/)
#
# - **PyTorch**
#   - [PyTorch Official Tutorials](https://pytorch.org/tutorials/)
#   - [PyTorch YouTube Channel](https://www.youtube.com/c/PyTorch)
#
# ---
#
# ## 6. Web Development & Deployment
#
# - **Flask**
#   - [Flask Mega-Tutorial](https://blog.miguelgrinberg.com/post/the-flask-mega-tutorial-part-i-hello-world)
#   - [Official Flask Documentation](https://flask.palletsprojects.com/en/2.2.x/)
#
# - **Streamlit**
#   - [Streamlit Documentation](https://docs.streamlit.io/)
#   - [Build Data Science Apps with Streamlit (YouTube)](https://www.youtube.com/watch?v=JwSS70SZdyM)
#
# ---
#
# ## 7. Containerization & DevOps
#
# - **Docker**
#   - [Docker Get Started Guide](https://docs.docker.com/get-started/)
#   - [Docker Tutorial for Beginners (YouTube)](https://www.youtube.com/watch?v=3c-iBn73dDE)
#
# - **Git & GitHub**
#   - [Git Handbook by GitHub](https://guides.github.com/introduction/git-handbook/)
#   - [GitHub Learning Lab](https://lab.github.com/)
#
# - **CI/CD with GitHub Actions**
#   - [GitHub Actions Documentation](https://docs.github.com/en/actions)
#
# ---
#
# ## 8. Databases
#
# - **SQL (PostgreSQL / MySQL)**
#   - [Mode Analytics SQL Tutorial](https://mode.com/sql-tutorial/)
#   - [W3Schools SQL Tutorial](https://www.w3schools.com/sql/)
#
# - **MongoDB**
#   - [MongoDB University Free Courses](https://university.mongodb.com/)
#
# ---
#
# ## 9. Big Data & Data Pipelines
#
# - **Apache Spark / PySpark**
#   - [Apache Spark Official Documentation](https://spark.apache.org/docs/latest/)
#   - [Databricks YouTube Channel](https://www.youtube.com/c/databricks)
#
# - **Apache Airflow**
#   - [Airflow Official Documentation](https://airflow.apache.org/docs/apache-airflow/stable/)
#
# - **Kafka**
#   - [Confluent Kafka Tutorials](https://developer.confluent.io/learn-kafka/)
#
# ---
#
# ## 10. Business Intelligence & Analytics
#
# - **Power BI**
#   - [Power BI Guided Learning](https://learn.microsoft.com/en-us/training/powerplatform/power-bi/)
#
# - **Tableau Public**
#   - [Tableau Free Training Videos](https://www.tableau.com/learn/training/20201)
#
# ---
#
# ## 11. NLP & Computer Vision (Optional Specializations)
#
# - **HuggingFace Transformers**
#   - [Hugging Face NLP Course](https://huggingface.co/learn/nlp-course/)
#
# ---
#
# ## 12. Portfolio & Personal Branding
#
# - **GitHub**
#   - [Awesome Data Science Repos](https://github.com/academic/awesome-datascience)
#
# - **LinkedIn**
#   - [LinkedIn Homepage](https://www.linkedin.com)
#
# - **Blogging Platforms**
#   - [Medium – Data Science Topics](https://medium.com/topic/data-science)
#
# ---

# %% [markdown]
# Python & Bash → Data Manipulation (NumPy, Pandas) → Visualization (Matplotlib, Seaborn, Plotly) → Machine Learning (Scikit-learn, XGBoost, MLflow) → Deep Learning (TensorFlow/Keras, PyTorch) → Web Development (Flask, Streamlit) → Containerization & DevOps (Docker, Git, CI/CD) → Databases (SQL, MongoDB) → Big Data (Spark, Airflow, Kafka) → Business Intelligence (Power BI, Tableau) → NLP/CV (HuggingFace) → Portfolio (GitHub, LinkedIn, Medium)
